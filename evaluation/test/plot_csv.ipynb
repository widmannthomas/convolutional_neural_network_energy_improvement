# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('~/acq0042.csv', sep=',',header=None)

df.describe()
# Out:
#          0            1
# count  0.0  8192.000000
# mean   NaN     0.000140
# std    NaN     0.002651
# min    NaN    -0.004175
# 25%    NaN    -0.002163
# 50%    NaN    -0.000151
# 75%    NaN     0.002532
# max    NaN     0.004545

# %%
plt.plot(df[1])
